# %%
# Instantiate the Choreo
likesChoreo = Likes(session)

# Get an InputSet object for the Choreo
likesInputs = likesChoreo.new_input_set()

# Set the Choreo inputs
likesInputs.set_Fields("id,name,category,created_time")
likesInputs.set_AccessToken("CAALlqqAD1ZBMBABDtmULMJGu1jp8hqrS0FH8bRMMrtH6fvjKzLdGtoMHG2YfL0RN4kEITt0XZC0m3AzxtOPTgHGWNkZBJW8dzfOPZAM3uvAsxvHgq0Awrcc1dEZCyJlcPUhSTNzooJIooZA5343vC6TWz4Vmwh7tclZCZAfdUDcfPbDEE0HLYC2ZCRx8nNb9JqiAZD")

# Execute the Choreo
likesResults = likesChoreo.execute_with_results(likesInputs)

# Print the Choreo outputs


import json
recent = json.loads(likesResults.get_HasNext())
recent = json.loads(likesResults.get_HasPrevious())
recent = json.loads(likesResults.get_Response())
import pprint
printer = pprint.PrettyPrinter(indent=4)
printer.pprint(recent)
# Out:
# {   u'data': [   {   u'category': u'Education',
#                      u'created_time': u'2016-01-27T15:54:43+0000',
#                      u'id': u'454084964763732',
#                      u'name': u"Daymond John's Launch Academy"},
#                  {   u'category': u'Clothing',
#                      u'created_time': u'2016-01-27T15:53:52+0000',
#                      u'id': u'777436372328438',
#                      u'name': u'BiG Believe In God'},
#                  {   u'category': u'Clothing',
#                      u'created_time': u'2016-01-27T15:53:16+0000',
#                      u'id': u'188527171219004',
#                      u'name': u'Sun-Staches'},
#                  {   u'category': u'Public Figure',
#                      u'created_time': u'2016-01-27T15:51:32+0000',
#                      u'id': u'185139171667',
#                      u'name': u'Daymond John'},
#                  {   u'category': u'Health/Beauty',
# ...
